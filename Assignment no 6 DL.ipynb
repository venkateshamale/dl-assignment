# %%
# example of using a pre-trained model as a classifier
from tensorflow.keras.utils import load_img
from tensorflow.keras.utils import img_to_array
from keras.applications.vgg16 import preprocess_input
from keras.applications.vgg16 import decode_predictions
from keras.applications.vgg16 import VGG16

# %%
image = load_img("tiger.jpg", target_size=(224, 224))

# %%
pip install scikit-image
# Out:
# Requirement already satisfied: scikit-image in c:\users\venkatesh amale\appdata\local\programs\python\python39\lib\site-packages (0.22.0)
# Requirement already satisfied: tifffile>=2022.8.12 in c:\users\venkatesh amale\appdata\local\programs\python\python39\lib\site-packages (from scikit-image) (2023.9.26)
# Requirement already satisfied: pillow>=9.0.1 in c:\users\venkatesh amale\appdata\local\programs\python\python39\lib\site-packages (from scikit-image) (9.5.0)
# Requirement already satisfied: imageio>=2.27 in c:\users\venkatesh amale\appdata\local\programs\python\python39\lib\site-packages (from scikit-image) (2.32.0)
# Requirement already satisfied: packaging>=21 in c:\users\venkatesh amale\appdata\local\programs\python\python39\lib\site-packages (from scikit-image) (23.1)
# Requirement already satisfied: scipy>=1.8 in c:\users\venkatesh amale\appdata\local\programs\python\python39\lib\site-packages (from scikit-image) (1.11.3)
# Requirement already satisfied: networkx>=2.8 in c:\users\venkatesh amale\appdata\local\programs\python\python39\lib\site-packages (from scikit-image) (3.2)
# Requirement already satisfied: lazy_loader>=0.3 in c:\users\venkatesh amale\appdata\local\programs\python\python39\lib\site-packages (from scikit-image) (0.3)
# Requirement already satisfied: numpy>=1.22 in c:\users\venkatesh amale\appdata\local\programs\python\python39\lib\site-packages (from scikit-image) (1.24.3)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 20.2.3; however, version 23.3.1 is available.
# You should consider upgrading via the 'c:\users\venkatesh amale\appdata\local\programs\python\python39\python.exe -m pip install --upgrade pip' command.

# %%
from skimage import io
img = io.imread("tiger.jpg")
io.imshow(img)

# %%
# convert the image pixels to a numpy array
image = img_to_array(image)

# %%
# reshape data for the model
image = image.reshape((1, image.shape[0], image.shape[1], image.shape[2]))

# %%
# prepare the image for the VGG model
image = preprocess_input(image)

# %%
# load the model
model = VGG16()

# %%
 # predict the probability across all output classes
yhat = model.predict(image)
# Out:
# 1/1 [==============================] - 1s 614ms/step

# %%
 # convert the probabilities to class labels
label = decode_predictions(yhat)

# %%
# retrieve the most likely result, e.g. highest probability
label = label[0][0]

# %%
# print the classification
print('%s (%.2f%%)' % (label[1], label[2]*100))
# Out:
# tiger (91.14%)

# %%
# load an image from file
image = load_img('tiger.jpg', target_size=(224, 224))

img1 = io.imread('tiger.jpg')
io.imshow(img1)

# convert the image pixels to a numpy array
image = img_to_array(image)
# reshape data for the model
image = image.reshape((1, image.shape[0], image.shape[1], image.shape[2]))
# prepare the image for the VGG model
image = preprocess_input(image)
# load the model
model = VGG16()

# %%
yhat = model.predict(image)
# convert the probabilities to class labels
label = decode_predictions(yhat)
# retrieve the most likely result, e.g. highest probability
label = label[0][0]
# print the classification
print('%s (%.2f%%)' % (label[1], label[2]*100))
# Out:
# 1/1 [==============================] - 0s 417ms/step
# tiger (91.14%)

# %%
# load an image from file
image = load_img('tiger.jpg', target_size=(224, 224))

img2 = io.imread('tiger.jpg')
io.imshow(img2)

# convert the image pixels to a numpy array
image = img_to_array(image)
# reshape data for the model
image = image.reshape((1, image.shape[0], image.shape[1], image.shape[2]))
# prepare the image for the VGG model
image = preprocess_input(image)
# load the model
model = VGG16()
# predict the probability across all output classes
yhat = model.predict(image)
# convert the probabilities to class labels
label = decode_predictions(yhat)
# retrieve the most likely result, e.g. highest probability
label = label[0][0]
# print the classification
print('%s (%.2f%%)' % (label[1], label[2]*100))
# Out:
# 1/1 [==============================] - 0s 440ms/step
# tiger (91.14%)
